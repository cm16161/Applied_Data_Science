# %%
import requests, json, regex, js2xml, re
from bs4 import BeautifulSoup, Comment

def get_crimes(data):
    crimes=["Anti-social behaviour","Bicycle theft","Burglary","Criminal damage and arson","Drugs","Other theft","Possession of weapons","Public order","Robbery","Shoplifting","Theft from the person","Vehicle crime","Violence and sexual offences","Other crime"]
    string = data[0]
    pattern= re.compile('\[[^)]+\]')
    string = string.strip()

    split = string.split('data: ',1)[1]
    raw_data= pattern.findall(split)[0]
    all_shit = []
    for i in raw_data.split('\n'):
        res = i.strip('][').split(', ')
        all_shit.append(res)

    numbers = []
    for i in all_shit:
        for word in i[-1].split('],'):
            if word.isdigit():
                numbers.append(int(word))

#     print(list(zip(crimes,numbers)))
#     print(sum(numbers))
    return list(zip(crimes,numbers)), sum(numbers)

def get_crime_data(postcode):
    postcode = postcode.replace(" ","%20")
    URL = 'https://www.crime-statistics.co.uk/postcode/'+postcode
    print("Getting Crime Data")
    page = requests.get(URL)
    pattern = regex.compile(r'\{(?:[^{}]|(?R))*\}')

    print("Parsing Response")
    soup = BeautifulSoup(page.content, 'html.parser')
    element = soup.find("div", id="divPieChart")
    script = element.find('script')

    print("Extracting Data")
    data = pattern.findall(str(script))

#     print ("getting crime statistics")
    return get_crimes(data)

# %%
import os
import glob
from difflib import SequenceMatcher
import Levenshtein

def get_maps(city):
    maps = []
    city = "results/"+city + "*"
    for file in glob.glob(city):
        maps.append(file)
    return maps


def get_closest_chimney(word):
    p_chimney = Levenshtein.ratio(word, "chimney")
    p_chy = Levenshtein.ratio(word, "chy")
    if p_chimney > p_chy:
        return p_chimney
    else:
        return p_chy

def get_locations(city):
    print("Getting Map Files")
    maps = get_maps(city)
    longs = []
    lats = []
#     word_file = open("words.txt", "a")
    print("Processing Map Files")
    for f in maps:
        ofile = open(f, 'r')
        for line in ofile:
            lat, long, blank, prob1, word, prob2 = line.split(',')
            word=word.replace('"','')
            p_use = get_closest_chimney(word)
            if(p_use > 0.8):
                longs.append(long)
                lats.append(lat)
    locations = set(zip(longs,lats))
    return locations

def hit_api(location):
    long, lat = location
#     print(location)
    URL = 'http://api.postcodes.io/postcodes?lon='+long+'&lat='+lat
    page = requests.get(URL)
    json_obj = json.loads(page.content)
    return json_obj

def get_postcode(city):
    print("Getting Chimney Locations")
    locations = get_locations(city)
#     print(locations)
    postcodes = []
    print("Getting Postcodes from Lat/Long")
    for location in locations:
        
#         long, lat = location
#         URL = 'http://api.postcodes.io/postcodes?lon='+long+'&lat='+lat
#         page = requests.get(URL)
        json_obj = hit_api(location)
        if json_obj["result"]:
            pc = json_obj["result"][0]['postcode']
#             postcodes.append(pc)
            postcodes.append((pc, location))
    print("Returning Unique Postcodes")
    return set(postcodes)

# %%
def crimes_by_city(city):
    print("Getting Postcodes of Chimneys in: " + city)
    postcodes = get_postcode(city)
    for pc in postcodes:
#         print("Getting Crime Data")
        breakdown, total = get_crime_data(pc[0])
        print()
        print("###########################################")
        print("POSTCODE: "+pc[0])
        print("CRIME BREAKDOWN:" + str(breakdown))
        print()
        print("TOTAL CRIMES = "+str(total))
        print("############################################")

# %%
crimes_by_city("Burnley")
# Out:
# Getting Postcodes of Chimneys in: Burnley
# Getting Chimney Locations
# Getting Map Files
# Processing Map Files
# Getting Postcodes from Lat/Long
# Returning Unique Postcodes
# Getting Crime Data
# Parsing Response
# Extracting Data
#
# ###########################################
# POSTCODE: BB11 1NL
# CRIME BREAKDOWN:[('Anti-social behaviour', 235), ('Bicycle theft', 2), ('Burglary', 22), ('Criminal damage and arson', 68), ('Drugs', 6), ('Other theft', 50), ('Possession of weapons', 4), ('Public order', 33), ('Robbery', 3), ('Shoplifting', 51), ('Theft from the person', 2), ('Vehicle crime', 26), ('Violence and sexual offences', 204), ('Other crime', 12)]
#
# TOTAL CRIMES = 718
# ############################################
# Getting Crime Data
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-180-542f8a296d32> in <module>
# ----> 1 crimes_by_city("Burnley")
#
# <ipython-input-178-d9522873f0a1> in crimes_by_city(city)
#       4     for pc in postcodes:
#       5 #         print("Getting Crime Data")
# ----> 6         breakdown, total = get_crime_data(pc[0])
#       7         print()
#       8         print("###########################################")
#
# <ipython-input-152-438eb72e6f9d> in get_crime_data(postcode)
#      30     URL = 'https://www.crime-statistics.co.uk/postcode/'+postcode
#      31     print("Getting Crime Data")
# ---> 32     page = requests.get(URL)
#      33     pattern = regex.compile(r'\{(?:[^{}]|(?R))*\}')
#      34
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     518         }
#     519         send_kwargs.update(settings)
# --> 520         resp = self.send(prep, **send_kwargs)
#     521
#     522         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     628
#     629         # Send the request
# --> 630         r = adapter.send(request, **kwargs)
#     631
#     632         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1354         try:
#    1355             try:
# -> 1356                 response.begin()
#    1357             except ConnectionError:
#    1358                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import csv

def accumulate_crime_data():
    crime_data = [['Longitude','Latitude','Crime Type']]
    for file in glob.glob("Crime-Data/2020-03*"):
        with open(file, newline='') as csvfile:
            spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
            next(spamreader)
            for row in spamreader:
#                 print(row)
                if row[4] == "":
                    continue
                else:
#                     obj = hit_api((row[4],row[5]))
#                     if obj["result"]:
#                         pc = obj["result"][0]['postcode']
                    crime_data.append([row[4],row[5],row[9]])
                    
    return crime_data

# print(accumulate_crime_data())

def write_crime_to_file(crime_data):        
    with open('all-crimes-postcodes-march-2020.csv', mode='w') as employee_file:
        crime_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        for row in crime_data:
            crime_writer.writerow(row)

            
def generate_crime_file():
    write_crime_to_file(accumulate_crime_data())

generate_crime_file()

# %%
import csv

def get_crime_data(file):
    crimes = []
    with open(file, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        next(spamreader)
        for row in spamreader:
            crimes.append([row[0],row[1],row[2]])
    return crimes

data = get_crime_data("all-crimes.csv")

# %%
# print(data[1])
# postcodes = []
# counter = -1
# for row in data:
#     counter+=1
#     print(str(counter)+"/"+str(len(data)))
#     obj = hit_api((row[0],row[1]))
#     if obj["result"]:
#         pc = obj["result"][0]['postcode']
#         postcodes.append(pc)
# print(postcodes)
# Out:
# ['-1.237805', '54.711196', 'Anti-social behaviour']
# 0/19329646
# 1/19329646
# 2/19329646
# 3/19329646
# 4/19329646
# 5/19329646
# 6/19329646
# 7/19329646
# 8/19329646
# 9/19329646
# 10/19329646
# 11/19329646
# 12/19329646
# 13/19329646
# 14/19329646
# 15/19329646
# 16/19329646
# 17/19329646
# 18/19329646
# 19/19329646
# 20/19329646
# 21/19329646
# 22/19329646
# 23/19329646
# 24/19329646
# 25/19329646
# 26/19329646
# 27/19329646
# 28/19329646
# 29/19329646
# 30/19329646
# 31/19329646
# 32/19329646
# 33/19329646
# 34/19329646
# 35/19329646
# 36/19329646
# 37/19329646
# 38/19329646
# 39/19329646
# 40/19329646
# 41/19329646
# 42/19329646
# 43/19329646
# 44/19329646
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-8f3b97f7eef7> in <module>
#       5     counter+=1
#       6     print(str(counter)+"/"+str(len(data)))
# ----> 7     obj = hit_api((row[0],row[1]))
#       8     if obj["result"]:
#       9         pc = obj["result"][0]['postcode']
#
# <ipython-input-18-3e99b04fe57f> in hit_api(location)
#      43 #     print(location)
#      44     URL = 'http://api.postcodes.io/postcodes?lon='+long+'&lat='+lat
# ---> 45     page = requests.get(URL)
#      46     json_obj = json.loads(page.content)
#      47     return json_obj
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     518         }
#     519         send_kwargs.update(settings)
# --> 520         resp = self.send(prep, **send_kwargs)
#     521
#     522         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     628
#     629         # Send the request
# --> 630         r = adapter.send(request, **kwargs)
#     631
#     632         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1354         try:
#    1355             try:
# -> 1356                 response.begin()
#    1357             except ConnectionError:
#    1358                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import pandas as pd

df  = pd.read_csv("all-crimes-postcodes-2020.csv")

# %%
import postcodes_io_api

def get_postcodes_from_api(dicts, postcodes):
    payload = {"geolocations":dicts}   
    data = api.get_bulk_reverse_geocode(payload)
    for indivObj in data['result']:
        try:
            postcodes.append(indivObj['result'][0]['postcode'])
        except:
            continue


api  = postcodes_io_api.Api(debug_http=False)

print(df.shape[0])
# postcodes = []

for i in range(14800,df.shape[0],100):
    print("Batch:" +str(i/100)+"/"+str(df.shape[0]/100))
    dicts = []
    for j in range(i,(i+100)):
        long,lat,crime = df.iloc[i]
        dicts.append({"longitude":long, "latitude":lat,"radius":1000})
    print("Getting Batch")
    get_postcodes_from_api(dicts,postcodes)
            

#     print(postcodes)
#     return postcodes

print(postcodes)
# Out:
# 478484
# Batch:148.0/4784.84
# Getting Batch
# Batch:149.0/4784.84
# Getting Batch
# Batch:150.0/4784.84
# Getting Batch
# Batch:151.0/4784.84
# Getting Batch
# Batch:152.0/4784.84
# Getting Batch
# Batch:153.0/4784.84
# Getting Batch
# Batch:154.0/4784.84
# Getting Batch
# Batch:155.0/4784.84
# Getting Batch
# Batch:156.0/4784.84
# Getting Batch
# Batch:157.0/4784.84
# Getting Batch
# Batch:158.0/4784.84
# Getting Batch
# Batch:159.0/4784.84
# Getting Batch
# Batch:160.0/4784.84
# Getting Batch
# Batch:161.0/4784.84
# Getting Batch
# Batch:162.0/4784.84
# Getting Batch
# Batch:163.0/4784.84
# Getting Batch
# Batch:164.0/4784.84
# Getting Batch
# Batch:165.0/4784.84
# Getting Batch
# Batch:166.0/4784.84
# Getting Batch
# Batch:167.0/4784.84
# Getting Batch
# Batch:168.0/4784.84
# Getting Batch
# Batch:169.0/4784.84
# Getting Batch
# Batch:170.0/4784.84
# Getting Batch
# Batch:171.0/4784.84
# Getting Batch
# Batch:172.0/4784.84
# Getting Batch
# Batch:173.0/4784.84
# Getting Batch
# Batch:174.0/4784.84
# Getting Batch
# Batch:175.0/4784.84
# Getting Batch
# Batch:176.0/4784.84
# Getting Batch
# Batch:177.0/4784.84
# Getting Batch
# Batch:178.0/4784.84
# Getting Batch
# Batch:179.0/4784.84
# Getting Batch
# Batch:180.0/4784.84
# Getting Batch
# Batch:181.0/4784.84
# Getting Batch
# Batch:182.0/4784.84
# Getting Batch
# Batch:183.0/4784.84
# Getting Batch
# Batch:184.0/4784.84
# Getting Batch
# Batch:185.0/4784.84
# Getting Batch
# Batch:186.0/4784.84
# Getting Batch
# Batch:187.0/4784.84
# Getting Batch
# Batch:188.0/4784.84
# Getting Batch
# Batch:189.0/4784.84
# Getting Batch
# Batch:190.0/4784.84
# Getting Batch
# Batch:191.0/4784.84
# Getting Batch
# Batch:192.0/4784.84
# Getting Batch
# Batch:193.0/4784.84
# Getting Batch
# Batch:194.0/4784.84
# Getting Batch
# Batch:195.0/4784.84
# Getting Batch
# Batch:196.0/4784.84
# Getting Batch
# Batch:197.0/4784.84
# Getting Batch
# Batch:198.0/4784.84
# Getting Batch
# Batch:199.0/4784.84
# Getting Batch
# Batch:200.0/4784.84
# Getting Batch
# Batch:201.0/4784.84
# Getting Batch
# Batch:202.0/4784.84
# Getting Batch
# Batch:203.0/4784.84
# Getting Batch
# Batch:204.0/4784.84
# Getting Batch
# Batch:205.0/4784.84
# Getting Batch
# Batch:206.0/4784.84
# Getting Batch
# Batch:207.0/4784.84
# Getting Batch
# Batch:208.0/4784.84
# Getting Batch
# Batch:209.0/4784.84
# Getting Batch
# Batch:210.0/4784.84
# Getting Batch
# Batch:211.0/4784.84
# Getting Batch
# Batch:212.0/4784.84
# Getting Batch
# Batch:213.0/4784.84
# Getting Batch
# Batch:214.0/4784.84
# Getting Batch
# Batch:215.0/4784.84
# Getting Batch
# Batch:216.0/4784.84
# Getting Batch
# Batch:217.0/4784.84
# Getting Batch
# Batch:218.0/4784.84
# Getting Batch
# Batch:219.0/4784.84
# Getting Batch
# Batch:220.0/4784.84
# Getting Batch
# Batch:221.0/4784.84
# Getting Batch
# Batch:222.0/4784.84
# Getting Batch
# Batch:223.0/4784.84
# Getting Batch
# Batch:224.0/4784.84
# Getting Batch
# Batch:225.0/4784.84
# Getting Batch
# Batch:226.0/4784.84
# Getting Batch
# Batch:227.0/4784.84
# Getting Batch
# Batch:228.0/4784.84
# Getting Batch
# Batch:229.0/4784.84
# Getting Batch
# Batch:230.0/4784.84
# Getting Batch
# Batch:231.0/4784.84
# Getting Batch
# Batch:232.0/4784.84
# Getting Batch
# Batch:233.0/4784.84
# Getting Batch
# Batch:234.0/4784.84
# Getting Batch
# Batch:235.0/4784.84
# Getting Batch
# Batch:236.0/4784.84
# Getting Batch
# Batch:237.0/4784.84
# Getting Batch
# Batch:238.0/4784.84
# Getting Batch
# Batch:239.0/4784.84
# Getting Batch
# Batch:240.0/4784.84
# Getting Batch
# Batch:241.0/4784.84
# Getting Batch
# Batch:242.0/4784.84
# Getting Batch
# Batch:243.0/4784.84
# Getting Batch
# Batch:244.0/4784.84
# Getting Batch
# Batch:245.0/4784.84
# Getting Batch
# Batch:246.0/4784.84
# Getting Batch
# Batch:247.0/4784.84
# Getting Batch
# Batch:248.0/4784.84
# Getting Batch
# Batch:249.0/4784.84
# Getting Batch
# Batch:250.0/4784.84
# Getting Batch
# Batch:251.0/4784.84
# Getting Batch
# Batch:252.0/4784.84
# Getting Batch
# Batch:253.0/4784.84
# Getting Batch
# Batch:254.0/4784.84
# Getting Batch
# Batch:255.0/4784.84
# Getting Batch
# Batch:256.0/4784.84
# Getting Batch
# Batch:257.0/4784.84
# Getting Batch
# Batch:258.0/4784.84
# Getting Batch
# Batch:259.0/4784.84
# Getting Batch
# Batch:260.0/4784.84
# Getting Batch
# Batch:261.0/4784.84
# Getting Batch
# Batch:262.0/4784.84
# Getting Batch
# Batch:263.0/4784.84
# Getting Batch
# Batch:264.0/4784.84
# Getting Batch
# Batch:265.0/4784.84
# Getting Batch
# Batch:266.0/4784.84
# Getting Batch
# Batch:267.0/4784.84
# Getting Batch
# Batch:268.0/4784.84
# Getting Batch
# Batch:269.0/4784.84
# Getting Batch
# Batch:270.0/4784.84
# Getting Batch
# Batch:271.0/4784.84
# Getting Batch
# Batch:272.0/4784.84
# Getting Batch
# Batch:273.0/4784.84
# Getting Batch
# Batch:274.0/4784.84
# Getting Batch
# Batch:275.0/4784.84
# Getting Batch
# Batch:276.0/4784.84
# Getting Batch
# Batch:277.0/4784.84
# Getting Batch
# Batch:278.0/4784.84
# Getting Batch
# Batch:279.0/4784.84
# Getting Batch
# Batch:280.0/4784.84
# Getting Batch
# Batch:281.0/4784.84
# Getting Batch
# Batch:282.0/4784.84
# Getting Batch
# Batch:283.0/4784.84
# Getting Batch
# Batch:284.0/4784.84
# Getting Batch
# Batch:285.0/4784.84
# Getting Batch
# Batch:286.0/4784.84
# Getting Batch
# Batch:287.0/4784.84
# Getting Batch
# Batch:288.0/4784.84
# Getting Batch
# Batch:289.0/4784.84
# Getting Batch
# Batch:290.0/4784.84
# Getting Batch
# Batch:291.0/4784.84
# Getting Batch
# Batch:292.0/4784.84
# Getting Batch
# Batch:293.0/4784.84
# Getting Batch
# Batch:294.0/4784.84
# Getting Batch
# Batch:295.0/4784.84
# Getting Batch
# Batch:296.0/4784.84
# Getting Batch
# Batch:297.0/4784.84
# Getting Batch
# Batch:298.0/4784.84
# Getting Batch
# Batch:299.0/4784.84
# Getting Batch
# Batch:300.0/4784.84
# Getting Batch
# Batch:301.0/4784.84
# Getting Batch
# Batch:302.0/4784.84
# Getting Batch
# Batch:303.0/4784.84
# Getting Batch
# Batch:304.0/4784.84
# Getting Batch
# Batch:305.0/4784.84
# Getting Batch
# Batch:306.0/4784.84
# Getting Batch
# Batch:307.0/4784.84
# Getting Batch
# Batch:308.0/4784.84
# Getting Batch
# Batch:309.0/4784.84
# Getting Batch
# Batch:310.0/4784.84
# Getting Batch
# Batch:311.0/4784.84
# Getting Batch
# Batch:312.0/4784.84
# Getting Batch
# Batch:313.0/4784.84
# Getting Batch
# Batch:314.0/4784.84
# Getting Batch
# Batch:315.0/4784.84
# Getting Batch
# Batch:316.0/4784.84
# Getting Batch
# Batch:317.0/4784.84
# Getting Batch
# Batch:318.0/4784.84
# Getting Batch
# Batch:319.0/4784.84
# Getting Batch
# Batch:320.0/4784.84
# Getting Batch
# Batch:321.0/4784.84
# Getting Batch
# Batch:322.0/4784.84
# Getting Batch
# Batch:323.0/4784.84
# Getting Batch
# Batch:324.0/4784.84
# Getting Batch
# Batch:325.0/4784.84
# Getting Batch
# Batch:326.0/4784.84
# Getting Batch
# Batch:327.0/4784.84
# Getting Batch
# Batch:328.0/4784.84
# Getting Batch
# Batch:329.0/4784.84
# Getting Batch
# Batch:330.0/4784.84
# Getting Batch
# Batch:331.0/4784.84
# Getting Batch
# Batch:332.0/4784.84
# Getting Batch
# Batch:333.0/4784.84
# Getting Batch
# Batch:334.0/4784.84
# Getting Batch
# Batch:335.0/4784.84
# Getting Batch
# Batch:336.0/4784.84
# Getting Batch
# Batch:337.0/4784.84
# Getting Batch
# Batch:338.0/4784.84
# Getting Batch
# Batch:339.0/4784.84
# Getting Batch
# Batch:340.0/4784.84
# Getting Batch
# Batch:341.0/4784.84
# Getting Batch
# Batch:342.0/4784.84
# Getting Batch
# Batch:343.0/4784.84
# Getting Batch
# Batch:344.0/4784.84
# Getting Batch
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-154-13dcad6acf51> in <module>
#      23         dicts.append({"longitude":long, "latitude":lat,"radius":1000})
#      24     print("Getting Batch")
# ---> 25     get_postcodes_from_api(dicts,postcodes)
#      26
#      27
#
# <ipython-input-154-13dcad6acf51> in get_postcodes_from_api(dicts, postcodes)
#       3 def get_postcodes_from_api(dicts, postcodes):
#       4     payload = {"geolocations":dicts}
# ----> 5     data = api.get_bulk_reverse_geocode(payload)
#       6     for indivObj in data['result']:
#       7         try:
#
# /usr/local/lib/python3.6/dist-packages/postcodes_io_api/api.py in get_bulk_reverse_geocode(self, payload_data)
#     170         """
#     171         url = '/postcodes'
# --> 172         response = self._make_request('POST', url, json=payload_data)
#     173         data = self._parse_json_data(response.content.decode('utf-8'))
#     174         return data
#
# /usr/local/lib/python3.6/dist-packages/postcodes_io_api/api.py in _make_request(self, http_method, url, data, json)
#     278                 response = self._session.post(url, data=data, timeout=self._timeout)
#     279             elif json:
# --> 280                 response = self._session.post(url, json=json, timeout=self._timeout)
#     281         return response
#     282
#
# /usr/lib/python3/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     565         """
#     566
# --> 567         return self.request('POST', url, data=data, json=json, **kwargs)
#     568
#     569     def put(self, url, data=None, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     518         }
#     519         send_kwargs.update(settings)
# --> 520         resp = self.send(prep, **send_kwargs)
#     521
#     522         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     628
#     629         # Send the request
# --> 630         r = adapter.send(request, **kwargs)
#     631
#     632         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1354         try:
#    1355             try:
# -> 1356                 response.begin()
#    1357             except ConnectionError:
#    1358                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print(postcodes)
# Out:
# ['CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'CH1 5AR', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1HB', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL30 1LG', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5EQ', 'LL18 5 ...

# %%
from OSGridConverter import latlong2grid

gridcodes = []

for row in df.iterrows():
    print(str(row[0])+"/"+str(df.shape[0]))
    gridcodes.append(latlong2grid(row[1][1],row[1][0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8fa83e5fc6c5> in <module>
#       3 gridcodes = []
#       4
# ----> 5 for row in df.iterrows():
#       6     print(str(row[0])+"/"+str(df.shape[0]))
#       7     gridcodes.append(latlong2grid(row[1][1],row[1][0]))
#
# NameError: name 'df' is not defined

# %%
df.to_csv('crimes-and-gridcode-6months-moregrain.csv',index = False)

# %%
import pandas as pd
df  = pd.read_csv("crimes-and-gridcode-6months.csv")
def grid_to_string(x):
    return str(x)[0:5]+" "+str(x)[9:11]

# print(grid_to_string(df['Grid Code'][0]))


df['Grid Code'] =df['Grid Code'].map(grid_to_string)
print(df)
# Out:
#          Longitude   Latitude                    Crime Type Grid Code
# 0        -2.036740  53.355936  Violence and sexual offences  SJ 97 84
# 1        -2.037296  53.356178  Violence and sexual offences  SJ 97 84
# 2        -2.033300  53.356791         Anti-social behaviour  SJ 97 84
# 3        -2.012417  53.359096         Anti-social behaviour  SJ 99 84
# 4        -2.023081  53.351445                      Burglary  SJ 98 83
# ...            ...        ...                           ...       ...
# 1461179  -4.085282  50.490167                  Public order  SX 52 67
# 1461180  -4.082940  50.488536         Anti-social behaviour  SX 52 67
# 1461181  -4.112227  50.487378         Anti-social behaviour  SX 50 67
# 1461182  -4.098160  50.486796  Violence and sexual offences  SX 51 67
# 1461183  -4.084066  50.491367  Violence and sexual offences  SX 52 67
#
# [1461184 rows x 4 columns]

# %%
print(df['Grid Code'])
# Out:
# 0          SJ 97 84
# 1          SJ 97 84
# 2          SJ 97 84
# 3          SJ 99 84
# 4          SJ 98 83
#              ...
# 1461179    SX 52 67
# 1461180    SX 52 67
# 1461181    SX 50 67
# 1461182    SX 51 67
# 1461183    SX 52 67
# Name: Grid Code, Length: 1461184, dtype: object

# %%
burnley_chim = get_locations("*")
chim_df = pd.DataFrame(burnley_chim, columns =['Longitude', 'Latitude'])

chimney_gridcodes =[]
for long,lat in burnley_chim:
    long = round(float(long),6)
    lat = round(float(lat),6)
    chimney_gridcodes.append(str(latlong2grid(lat,long)))

print(len(chimney_gridcodes))
print(chim_df.shape)
chim_df["Grid Code"] = chimney_gridcodes
# print(chim_df["Grid Code"])
chim_df["Grid Code"] = chim_df["Grid Code"].map(grid_to_string)
# print(df)
# print (chim_df["Grid Code"][0])
df.loc[df['Grid Code'] == chim_df["Grid Code"][0]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b01c4abc956a> in <module>
# ----> 1 burnley_chim = get_locations("*")
#       2 chim_df = pd.DataFrame(burnley_chim, columns =['Longitude', 'Latitude'])
#       3
#       4 chimney_gridcodes =[]
#       5 for long,lat in burnley_chim:
#
# NameError: name 'get_locations' is not defined
